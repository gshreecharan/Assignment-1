# %%
#1
fruits=["mango","apple","kiwi","banana","grape"]
a=fruits[1:5:3]
print(a)
# Out:
# ['apple', 'grape']

# %%
#2
city1=input()
city2=input()
city3=input()
list1=[]
list1.append(city1)
list1.append(city2)
list1.append(city3)
print(list1)
# Out:
#  vizag
#  hyderabad
#  vijayawada
# ['vizag', 'hyderabad', 'vijayawada']

# %%
#3
prices=[1200,1000,950,520]
prices.sort()
print(prices)
a=prices[2:4]
print(a)
# Out:
# [520, 950, 1000, 1200]
# [1000, 1200]

# %%
#4
even=[2,4,6,8,10]
list1=[12]

print(even+list1)
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
#5
lang=['java','c++','go']
# lang[2]='python'
# print(lang)
lang.insert(2,'python')
print(lang)
# Out:
# ['java', 'c++', 'python', 'go']

# %%
#6
sentence=input()
v=sentence.split()
print(v)
# Out:
#  i am bad boy
# ['i', 'am', 'bad', 'boy']

# %%
#7
months =['Jan', 'Feb', 'Mar', 'Apr']
months.remove('Apr')
print(months)
# Out:
# ['Jan', 'Feb', 'Mar']

# %%
#8
list1= ['car', 'bus', 'train']
list1.sort()
print(list1)
v=list1[::-1]
print(v)
# Out:
# ['bus', 'car', 'train']
# ['train', 'car', 'bus']

# %%
#9
fruits= ['apple', 'banana', 'apple', 'cherry']
v=fruits.count('apple')
print(v)
# Out:
# 2

# %%
#10
apples=3
bananas=5
print("tom has {} apples and {} bananas".format(apples,bananas))
# Out:
# tom has 3 apples and 5 bananas

# %%
#11
list1='hello'
print(list(list1))
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
#12
list1=[1,2,3]
sum=list1[0]+list1[1]+list1[2]
avg=sum/3
print(sum,avg)
# Out:
# 6 2.0

# %%
name=input()
print(list(name))
v=name[::-1]
print(list(v))
# Out:
#  Shree Charan
# ['S', 'h', 'r', 'e', 'e', ' ', 'C', 'h', 'a', 'r', 'a', 'n']
# ['n', 'a', 'r', 'a', 'h', 'C', ' ', 'e', 'e', 'r', 'h', 'S']

# %%
names = ['Alice', 'Bob', 'Charlie']
res='Bob' in names
print(res)
# Out:
# True

# %%
list1= ['one', 'two', 'three'] 
list1.clear()
print(list1)
# Out:
# []

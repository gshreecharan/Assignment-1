# %%
# 1
foods = {'Pizza': 250, 'Burger': 150, 'Pasta': 200}
print(foods)

# %%
# # 2
data = input("Enter 3 subjects and their marks separated by spaces: ").split()
marks_dict = {data[i]: int(data[i+1]) for i in range(0, len(data), 2)}
print("Subject and Marks Dictionary:", marks_dict)
# Out:
# Enter 3 subjects and their marks separated by spaces:  Maths 80 physics 90 chemistry 70
# Subject and Marks Dictionary: {'Maths': 80, 'physics': 90, 'chemistry': 70}

# %%
# 3
student = {'name': 'John', 'age': 18, 'grade': 'A'}
student['city'] = 'New York'
print(student)

# %%
# 4
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}
d1.update(d2)
print(d1)

# %%
# 5
person_a = {'Python': 'Advanced', 'Java': 'Intermediate'}
person_b = {'C++': 'Beginner', 'SQL': 'Intermediate'}
combined = {**person_a, **person_b}
print(combined)

# %%
# 6
fruits = {'apple': 5, 'banana': 3, 'orange': 8}
print(fruits.keys())

# %%
# 7
colors = {'red': '#FF0000', 'green': '#00FF00', 'blue': '#0000FF'}
print(colors.values())

# %%
# 8
items = {'pen': 2, 'pencil': 5, 'eraser': 1}
removed = items.pop('pencil')
print("Removed:", removed)
print("Updated:", items)

# %%
# 9
stationery = {'pen': 2, 'eraser': 1}
print(stationery.get('marker'))

# %%
# 10
cars = {'Toyota': 2018, 'Ford': 2020, 'BMW': 2022}
removed = cars.popitem()
print("Removed:", removed)
# Out:
# Removed: ('BMW', 2022)

# %%
# 11
books = {'Book1': 'Author1', 'Book2': 'Author2'}
books.clear()
print(books)
# Out:
# {}

# %%
# 12
tools = {'hammer': 1, 'screwdriver': 2}
del tools
print(tools)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_35/3324331615.py in <cell line: 0>()
#       2 tools = {'hammer': 1, 'screwdriver': 2}
#       3 del tools
# ----> 4 print(tools)
#
# NameError: name 'tools' is not defined

# %%
# 13
keys = ['name', 'age', 'city']
values = ['John', 25, 'NYC']
person = dict(zip(keys, values))
print(person)
# Out:
# {'name': 'John', 'age': 25, 'city': 'NYC'}

# %%
# 14

words = input("Enter 5 words separated by space: ").split()
freq = {
    words[0]: words.count(words[0]),
    words[1]: words.count(words[1]),
    words[2]: words.count(words[2]),
    words[3]: words.count(words[3]),
    words[4]: words.count(words[4]),
}

print("Word Frequency Dictionary:", freq)
# Out:
# Enter 5 words separated by space:  HERO DIRECTOR COMEDIAN HEROINE DANCER
# Word Frequency Dictionary: {'HERO': 1, 'DIRECTOR': 1, 'COMEDIAN': 1, 'HEROINE': 1, 'DANCER': 1}

# %%
# 15
d = {'x': 10, 'y': 20, 'z': 30}
Above_15 = dict([('y', d['y']), ('z', d['z'])])
print("New Dictionary:", Above_15)
# Out:
# New Dictionary: {'y': 20, 'z': 30}

# %%
# 16
movies = {'Maghadheera': 2010, 'Rangasthalam': 2018, 'RRR': 2022}
print("Number of movies:", len(movies))
# Out:
# Number of movies: 3

# %%
# 17
langs = {'java': 1995, 'python': 1991, 'c++': 1985}
print('python' in langs)
# Out:
# True

# %%
# 18
student = {
    'personal': {'name': 'Alice', 'age': 17},
    'grades': {'math': 95, 'science': 90}
}
print(student['grades']['math'])
# Out:
# 95

# %%
# 19
s = 'hello'
ascii_dict = {char: ord(char) for char in s}
print(ascii_dict)
# Out:
# {'h': 104, 'e': 101, 'l': 108, 'o': 111}

# %%
# 20

A = {'a': 1, 'b': 2}
copy_A = original.copy()
copy_A['a'] = 100
print("Original:", A)
print("Copy:", copy_A)
# Out:
# Original: {'a': 1, 'b': 2}
# Copy: {'a': 100, 'b': 2}
